# %% [markdown]
# Tasks:
#
# 1.Task- Explore Merge function
#
# 2.TASK- Challenge to Clean the Data.
#
# 3.TASK- Explore Aggregrate function.

# %% [markdown]
# ### Data Cleaning in Pandas

# %%
import pandas as pd
import numpy as np

# %%
sales_2017= pd.read_csv("D:\ProITBridge\Beginner\Day6\Sales Transactions-2017.csv")
sales_2017
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2018= pd.read_csv("D:\ProITBridge\Beginner\Day6\Sales Transactions-2018.csv")
sales_2018
# Out:
#              Date   Voucher        Party            Product           Qty  \
# 0        1/4/2018   Sal:146         TP13  SILVER POUCH 9*12            50
# 1        1/4/2018   Sal:146         TP13             RUBBER             5
# 2        1/4/2018   Sal:146         TP13   DURGA 10*12 Blue      1,600.00
# 3        1/4/2018   Sal:146         TP13   DURGA 13*16 BLUE           400
# 4        1/4/2018   Sal:146         TP13    10*12 SARAS-NAT           600
# ...           ...       ...          ...                ...           ...
# 44735  31/03/2019  Sal:9610  HAMPI FOODS        SPOON SOOFY           200
# 44736         NaN       NaN          NaN                NaN           NaN
# 44737         NaN       NaN          NaN                NaN           NaN
# 44738         NaN   Total            NaN                NaN    666,056.00
# 44739         NaN   Total            NaN                NaN  7,097,803.00
#
#                 Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2019=pd.read_csv("D:\ProITBridge\Beginner\Day6\Sales Transactions-2019.csv")
sales_2019
# Out:
#              Date   Voucher            Party         Product           Qty  \
# 0        1/4/2019   Sal:687  BALAJI PLASTICS   DONA-VAI-9100             1
# 1        1/4/2019   Sal:687  BALAJI PLASTICS  SMART BOUL(48)             1
# 2        1/4/2019   Sal:688  BALAJI PLASTICS      Vishnu Ice           110
# 3                                       28/3                             0
# 4        1/4/2019   Sal:689  BALAJI PLASTICS     100LEAF -SP             3
# ...           ...       ...              ...             ...           ...
# 19171  10/10/2019  Sal:4935        K.SRIHARI  13*16 WHITE RK           400
# 19172         NaN       NaN              NaN             NaN           NaN
# 19173         NaN       NaN              NaN             NaN           NaN
# 19174         NaN   Total                NaN             NaN     99,284.90
# 19175         NaN   Total                NaN             NaN  2,710,193.00
#
#                Rate          Gross        Disc Voucher Amount
# ...

# %%
sales_complete_data=pd.concat([sales_2017,sales_2018,sales_2019])
sales_complete_data
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
df=sales_complete_data.drop_duplicates()
df
# Out:
#              Date   Voucher               Party              Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100
# ...           ...       ...                 ...                  ...
# 19169  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN
# 19170  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK
# 19171  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK
# 19174         NaN   Total                   NaN                  NaN
# 19175         NaN   Total                   NaN                  NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# ...

# %%
pd.set_option("display.max_columns", None)

# %%
df
# Out:
#              Date   Voucher               Party              Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100
# ...           ...       ...                 ...                  ...
# 19169  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN
# 19170  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK
# 19171  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK
# 19174         NaN   Total                   NaN                  NaN
# 19175         NaN   Total                   NaN                  NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# ...

# %%
df["Party"]= df["Party"].str.lstrip(" ")

df
# Out:
# C:\Users\subhe\AppData\Local\Temp/ipykernel_23668/1860396838.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Party"]= df["Party"].str.lstrip(" ")
#              Date   Voucher               Party              Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100
# ...           ...       ...                 ...                  ...
# 19169  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN
# ...

# %%
df.shape
# Out:
# (96624, 9)

# %%
df.isnull()
# Out:
#         Date  Voucher  Party  Product    Qty   Rate  Gross   Disc  \
# 0      False    False  False    False  False  False  False   True
# 1      False    False  False    False  False  False  False   True
# 2      False    False  False    False  False  False  False   True
# 3      False    False  False    False  False  False  False   True
# 4      False    False  False    False  False  False  False   True
# ...      ...      ...    ...      ...    ...    ...    ...    ...
# 19169  False    False  False    False  False  False  False   True
# 19170  False    False  False    False  False  False  False   True
# 19171  False    False  False    False  False  False  False   True
# 19174   True    False   True     True  False  False  False  False
# 19175   True    False   True     True  False  False  False  False
#
#        Voucher Amount
# 0               False
# 1                True
# 2               False
# 3                True
# 4                True
# ...               ...
# ...

# %% [markdown]
# ### Handling missing values

# %%
df.isna().sum()
# Out:
# Date                204
# Voucher             170
# Party                35
# Product             204
# Qty                 170
# Rate                171
# Gross               171
# Disc              92951
# Voucher Amount    70984
# dtype: int64

# %%
missing_values= ["N/A","na",np.nan]
df_2017=pd.read_csv("D:\ProITBridge\Beginner\Day6\Sales Transactions-2017.csv",na_values=missing_values)

# %%
df_2017
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
df_2017.isnull().sum()          # Null values with Duplicates
# Out:
# Date               5388
# Voucher            5375
# Party                15
# Product            5388
# Qty                5375
# Rate               5376
# Gross              5376
# Disc              44432
# Voucher Amount    35942
# dtype: int64

# %%
missing_values= ["N/A","na",np.nan]
df_2018=pd.read_csv("D:\ProITBridge\Beginner\Day6\Sales Transactions-2018.csv",na_values=missing_values)

# %%
df_2018.isnull().sum()       # Null values with Duplicates
# Out:
# Date               5413
# Voucher            5400
# Party                15
# Product            5413
# Qty                5400
# Rate               5400
# Gross              5400
# Disc              42778
# Voucher Amount    33916
# dtype: int64

# %%
missing_values= ["N/A","na",np.nan]
df_2019=pd.read_csv("D:\ProITBridge\Beginner\Day6\Sales Transactions-2019.csv",na_values=missing_values)

# %%
df_2019.isnull().sum()       # Null values with Duplicates
# Out:
# Date               1790
# Voucher            1782
# Party                10
# Product            1790
# Qty                1782
# Rate               1782
# Gross              1782
# Disc              18399
# Voucher Amount    13788
# dtype: int64

# %%
df
# Out:
#              Date   Voucher               Party              Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100
# ...           ...       ...                 ...                  ...
# 19169  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN
# 19170  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK
# 19171  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK
# 19174         NaN   Total                   NaN                  NaN
# 19175         NaN   Total                   NaN                  NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# ...

# %%
df.isnull().sum()  #After deleting Duplicates (It is the complete sales_data)
# Out:
# Date                204
# Voucher             170
# Party                35
# Product             204
# Qty                 170
# Rate                171
# Gross               171
# Disc              92951
# Voucher Amount    70984
# dtype: int64

# %%
df.dropna(how="all")
# Out:
#              Date   Voucher               Party              Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100
# ...           ...       ...                 ...                  ...
# 19169  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN
# 19170  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK
# 19171  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK
# 19174         NaN   Total                   NaN                  NaN
# 19175         NaN   Total                   NaN                  NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# ...

# %%
df_dropped= df.fillna(0)          # Fill the Null_values with 0

# %%
df_dropped
# Out:
#              Date   Voucher               Party              Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100
# ...           ...       ...                 ...                  ...
# 19169  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN
# 19170  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK
# 19171  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK
# 19174           0   Total                     0                    0
# 19175           0   Total                     0                    0
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# ...

# %%
df_dropped= df_dropped.rename(columns= {"Date":"Dates","Voucher":"Vouchers","Party":"Party","Product":"Products"
                             ,"Qty":"Quantity","Rate":"Rate","Gross":"Gross","Disc":"Disc",
                              "Voucher Amount":"Voucher Amount"})

# %%
df_dropped.head()                 # Renaming the Column Names
# Out:
#       Dates Vouchers               Party           Products Quantity  \
# 0  1/4/2017    Sal:1    SOLANKI PLASTICS      DONA-VAI-9100        2
# 1  1/4/2017    Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)        6
# 2  1/4/2017    Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE      500
# 3  1/4/2017    Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)        6
# 4  1/4/2017    Sal:2  SARNESWARA TRADERS      DONA-VAI-9100        5
#
#        Rate      Gross Disc Voucher Amount
# 0  1,690.00   3,380.00    0      13,100.00
# 1  1,620.00   9,720.00    0              0
# 2        23  11,500.00    0      30,990.00
# 3  1,620.00   9,720.00    0              0
# 4  1,690.00   8,450.00    0              0

# %%
df_dropped["Dates"].str.split(pat= '-')
# Out:
# 0          [1/4/2017]
# 1          [1/4/2017]
# 2          [1/4/2017]
# 3          [1/4/2017]
# 4          [1/4/2017]
#              ...
# 19169    [10/10/2019]
# 19170    [10/10/2019]
# 19171    [10/10/2019]
# 19174             NaN
# 19175             NaN
# Name: Dates, Length: 96624, dtype: object
